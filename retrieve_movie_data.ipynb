# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL

query_url = (
    f"{url}"
    f"q=love&"  # General search term for keyword 'love'
    f"fq={filter_query}&"  # Filter query for section, type, and headline
    f"sort={sort}&"  # Sort by newest
    f"fl={field_list}&"  # Fields to return
    f"begin_date={begin_date}&"  # Start date for search
    f"end_date={end_date}&"  # End date for search
    f"api-key={nyt_api_key}"  # Your API key
)

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    # API results show 10 articles at a time
    query_url_with_page = f"{query_url}&page={page}"
    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(query_url_with_page)
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        reviews = response.json()
        if 'response' in reviews and 'docs' in reviews['response']:
            for review in reviews['response']['docs']:
                reviews_list.append(review)

            # Print the page that was just retrieved
            print(f"Page {page} retrieved successfully.")
        else:

            # Print the page number that had no results then break from the loop
            print(f"Page {page} had no results.")
            break
    # Handle any errors
    except Exception as e:
        print(f"Error on page {page}: {str(e)}")
        break
# Out:
# Page 0 retrieved successfully.
# Page 1 retrieved successfully.
# Page 2 retrieved successfully.
# Page 3 retrieved successfully.
# Page 4 retrieved successfully.
# Page 5 retrieved successfully.
# Page 6 retrieved successfully.
# Page 7 retrieved successfully.
# Page 8 retrieved successfully.
# Page 9 retrieved successfully.
# Page 10 retrieved successfully.
# Page 11 retrieved successfully.
# Page 12 retrieved successfully.
# Page 13 retrieved successfully.
# Page 14 retrieved successfully.
# Page 15 retrieved successfully.
# Page 16 retrieved successfully.
# Page 17 retrieved successfully.
# Page 18 retrieved successfully.
# Page 19 retrieved successfully.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

first_five_reviews = reviews_list[:5]

for i, review in enumerate(first_five_reviews):
    formatted_review = json.dumps(review, indent=4)
    print(f"Review {i+1}:")
    print(formatted_review)
    print("\n" + "="*80 + "\n")
# Out:
# Review 1:
# {
#     "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#     "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "The Attachment Diaries",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "The Attachment Diaries (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Diment, Valentin Javier",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-25T11:00:03+0000",
#     "byline": {
#         "original": "By Jeannette Catsoulis",
#         "person": [
#             {
#                 "firstname": "Jeannette",
#                 "middlename": null,
#                 "lastname": "Catsoulis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 295
# }
#
# ================================================================================
#
# Review 2:
# {
#     "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#     "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "What\u2019s Love Got to Do With It?",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Kapur, Shekhar",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "James, Lily",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Azmi, Shabana",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Thompson, Emma",
#             "rank": 5,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-04T17:16:45+0000",
#     "byline": {
#         "original": "By Jeannette Catsoulis",
#         "person": [
#             {
#                 "firstname": "Jeannette",
#                 "middlename": null,
#                 "lastname": "Catsoulis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 287
# }
#
# ================================================================================
#
# Review 3:
# {
#     "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#     "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "You Can Live Forever",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "You Can Live Forever (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Slutsky, Mark",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Watts, Sarah (Film Director)",
#             "rank": 4,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "O'Driscoll, Anwen",
#             "rank": 5,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Laporte, June (Actor)",
#             "rank": 6,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-05-04T11:00:08+0000",
#     "byline": {
#         "original": "By Elisabeth Vincentelli",
#         "person": [
#             {
#                 "firstname": "Elisabeth",
#                 "middlename": null,
#                 "lastname": "Vincentelli",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 294
# }
#
# ================================================================================
#
# Review 4:
# {
#     "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#     "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "A Tourist\u2019s  Guide to Love",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "A Tourist's Guide to Love (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Tsuchida, Steven",
#             "rank": 3,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Cook, Rachael Leigh",
#             "rank": 4,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-04-21T07:03:25+0000",
#     "byline": {
#         "original": "By Elisabeth Vincentelli",
#         "person": [
#             {
#                 "firstname": "Elisabeth",
#                 "middlename": null,
#                 "lastname": "Vincentelli",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 276
# }
#
# ================================================================================
#
# Review 5:
# {
#     "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#     "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#         "kicker": "Critic\u2019s pick",
#         "content_kicker": null,
#         "print_headline": "Intoxicating Love With a Sobering Turn",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Zlotowski, Rebecca",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "Other People's Children (Movie)",
#             "rank": 3,
#             "major": "N"
#         }
#     ],
#     "pub_date": "2023-04-20T15:35:13+0000",
#     "byline": {
#         "original": "By Manohla Dargis",
#         "person": [
#             {
#                 "firstname": "Manohla",
#                 "middlename": null,
#                 "lastname": "Dargis",
#                 "qualifier": null,
#                 "title": null,
#                 "role": "reported",
#                 "organization": "",
#                 "rank": 1
#             }
#         ],
#         "organization": null
#     },
#     "word_count": 801
# }
#
# ================================================================================

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

df_reviews = pd.json_normalize(reviews_list)
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
#
[{'firstname': 'Teo', 'middlename': None, 'las...                None
#
#                                 title
# 0       The Attachment Diaries’ Revie
# 1
# 2         You Can Live Forever’ Revie
# 3    A Tourist’s Guide to Love’ Revie
# 4      Other People’s Children’ Revie
# ..                                ...
# 215    Lady Chatterley’s Lover’ Revie
# 216     The Sound of Christmas’ Revie
# 217             The Inspection’ Revie
# 218              Bones and All’ Revie
# 219               My Policeman’ Revie
#
# [220 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
df_reviews['keywords'] = df_reviews['keywords'].apply(extract_keywords)
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 215  https://www.nytimes.com/2022/12/01/movies/lady...
# 216  https://www.nytimes.com/2022/11/23/movies/soun...
# 217  https://www.nytimes.com/2022/11/17/movies/the-...
# 218  https://www.nytimes.com/2022/11/17/movies/bone...
# 219  https://www.nytimes.com/2022/10/20/movies/my-p...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 215  The new Netflix adaptation of D.H. Lawrence’s ...  The New York Times
# 216  A young singer gets more than she bargained fo...  The New York Times
# 217  Elegance Bratton’s autobiographical first feat...  The New York Times
# 218  Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# 219  A schoolteacher, her police officer husband an...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 215  subject: Movies;creative_works: Lady Chatterle...
# 216  subject: Movies;persons: Ne-Yo;creative_works:...
# 217  subject: Movies;creative_works: The Inspection...
# 218  subject: Movies;creative_works: Bones and All ...
# 219  subject: Movies;creative_works: My Policeman (...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 215  2022-12-01T16:40:55+0000         768
# 216  2022-11-23T15:00:09+0000         277
# 217  2022-11-17T12:00:07+0000         836
# 218  2022-11-17T12:00:06+0000         710
# 219  2022-10-20T16:52:51+0000         303
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 215  ‘Lady Chatterley’s Lover’ Review: When Connie ...            None
# 216  ‘The Sound of Christmas’ Review: A Gospel Sing...            None
# 217   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 218       ‘Bones and All’ Review: You Eat What You Are            None
# 219  ‘My Policeman’ Review: Two Love Affairs, Equal...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 215                    None
# 216                    None
# 217                    None
# 218                    None
# 219                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 215                  A Love Whose Name Is Often Spoken          None
# 216                            The Sound  Of Christmas          None
# 217                  A Few Good Men, Some With Secrets          None
# 218  It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# 219                                       My Policeman          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 215         None         None             By A.O. Scott
# 216         None         None     By Concepción de León
# 217         None         None             By A.O. Scott
# 218         None         None             By A.O. Scott
# 219         None         None             By Teo Bugbee
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 215  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 216  [{'firstname': 'Concepción', 'middlename': Non...                None
# 217  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 218  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 219  [{'firstname': 'Teo', 'middlename': None, 'las...                None
#
#                                 title
# 0       The Attachment Diaries’ Revie
# 1
# 2         You Can Live Forever’ Revie
# 3    A Tourist’s Guide to Love’ Revie
# 4      Other People’s Children’ Revie
# ..                                ...
# 215    Lady Chatterley’s Lover’ Revie
# 216     The Sound of Christmas’ Revie
# 217             The Inspection’ Revie
# 218              Bones and All’ Revie
# 219               My Policeman’ Revie
#
# [220 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database

df_reviews['title'] = df_reviews['headline.main'].apply(
    lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")]
)

titles = df_reviews['title'].to_list()
for title in titles:
    print(title)
# Out:
# The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo
# You Can Live Forever
# A Tourist’s Guide to Love
# Other People’s Children
# One True Loves
# The Lost Weekend: A Love Story
# A Thousand and One
# Your Place or Mine
# Love in the Time of Fentanyl
# Pamela, a Love Story
# In From the Side
# After Love
# Alcarràs
# Nelly & Nadine
# Lady Chatterley’s Lover
# The Sound of Christmas
# The Inspection
# Bones and All
# My Policeman
# About Fate
# Waiting for Bojangles
# I Love My Dad
# A Love Song
# Alone Together
# Art of Love
# The Wheel
# Thor: Love and Thunder
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# I Do ... Until I Don’t,’ Love and Loathing in Florid
# Tales of an Immoral Couple’: Love Means Having to Grow U
# After Love’ and Regretting Every Momen
# The Last Face
# Women Who Kill,’ and May Be in Love With On
# False Confessions,’ the Play’s Not Quite the Thin
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# The Big Sick,’ Comedy Is Hard, Love Harde
# Lost in Paris
# Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# Everything, Everything’ Pits Love Against Diseas
# Hounds of Love’ Is Tense and Deadly Down Unde
# Harold and Lillian’ Introduces a Hollywood Power Coupl
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope
# The Promise’ Finds a Love Triangle in Constantinopl
# Frantz,’ a Mysterious Frenchman and the Wounds of Wa
# The Other Half
# The Ottoman Lieutenant
# Love & Taxes
# Everybody Loves Somebody,’ a Rom-Com With Bit
# Kedi,’ Rekindling a ‘Love of Life

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        print("Sleeping for a moment to respect API limits...")
        time.sleep(1)

    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    search_url = f"{url}{title}{tmdb_key_string}"
    search_response = requests.get(search_url).json()


    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = search_response['results'][0]['id']

        # Make a request for a the full movie details
        movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
        movie_response = requests.get(movie_url).json()

        # Execute "GET" request with url
        movie_response = requests.get(movie_url).json()
        
        # Extract the genre names into a list
        genres = [genre['name'] for genre in movie_response.get('genres', [])]

        # Extract the spoken_languages' English name into a list
        spoken_languages = [language['english_name'] for language in movie_response.get('spoken_languages', [])]

        # Extract the production_countries' name into a list
        production_countries = [country['name'] for country in movie_response.get('production_countries', [])]
    
        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_data = {
            'title': movie_response.get('title', ''),
            'original_title': movie_response.get('original_title', ''),
            'budget': movie_response.get('budget', 0),
            'original_language': movie_response.get('original_language', ''),
            'homepage': movie_response.get('homepage', ''),
            'overview': movie_response.get('overview', ''),
            'popularity': movie_response.get('popularity', 0),
            'runtime': movie_response.get('runtime', 0),
            'revenue': movie_response.get('revenue', 0),
            'release_date': movie_response.get('release_date', ''),
            'vote_average': movie_response.get('vote_average', 0),
            'vote_count': movie_response.get('vote_count', 0),
            'genres': genres,
            'spoken_languages': spoken_languages,
            'production_countries': production_countries
        }
        tmdb_movies_list.append(movie_data)
        
        # Print out the title that was found
        print(f"Found {movie_data['title']}")
    except (IndexError, KeyError):
         print(f"{title} not found.")
# Out:
# Found The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever
# Found A Tourist's Guide to Love
# Found Other People's Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, A Love Story
# Found In from the Side
# Found After Love
# Found Alcarràs
# Found Nelly Knows Mysteries: A Fatal Engagement
# Found Lady Chatterley's Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found 2099: The Soldier Protocol
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Mektoub, My Love
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# Found See You Then
# Found La Mami
# Found After Love
# Found Deep Water
# Found Lucy and Desi
# Found Cyrano
# Found The In Between
# Found Book of Love
# Found Lingui: The Sacred Bonds
# Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre not found.
# Keep the Change,’ Two People With Autism Find Lov not found.
# Found The Party
# The Housemaid,’ Twisted Love and Angry Ghosts in Vietna not found.
# Forever My Girl,’ a Romance Resumes After a Long Brea not found.
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr not found.
# Found Lover for a Day
# Youth,’ the People’s Dance Troupe, in Love and Wa not found.
# Killing for Love’ Revisits a Virginia Murder Cas not found.
# The Shape of Water’ Is Altogether Wonderfu not found.
# Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr not found.
# Cuba and the Cameraman’ Lavishes Love on a Country … and Castr not found.
# On the Beach at Night Alone’ Zooms in on a Love Affai not found.
# Thelma,’ a Woman in Love Can Burn Down the Worl not found.
# Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade not found.
# It Happened in L.A.,’ All That Questing After Lov not found.
# Found God's Own Country
# Found The Mountain Between Us
# Dina,’ a Differently Abled Love Stor not found.
# Found In Search of Fellini
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen not found.
# I Do ... Until I Don’t,’ Love and Loathing in Florid not found.
# Tales of an Immoral Couple’: Love Means Having to Grow U not found.
# After Love’ and Regretting Every Momen not found.
# Found The Last Face
# Women Who Kill,’ and May Be in Love With On not found.
# False Confessions,’ the Play’s Not Quite the Thin not found.
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem not found.
# The Big Sick,’ Comedy Is Hard, Love Harde not found.
# Found Lost in Paris
# Vincent N Roxxy,’ Love Is in the Air, N So Is Fea not found.
# Everything, Everything’ Pits Love Against Diseas not found.
# Hounds of Love’ Is Tense and Deadly Down Unde not found.
# Harold and Lillian’ Introduces a Hollywood Power Coupl not found.
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope not found.
# The Promise’ Finds a Love Triangle in Constantinopl not found.
# Frantz,’ a Mysterious Frenchman and the Wounds of Wa not found.
# Found The Other Half
# Found The Ottoman Lieutenant
# Found Mektoub, My Love
# Everybody Loves Somebody,’ a Rom-Com With Bit not found.
# Sleeping for a moment to respect API limits...
# Kedi,’ Rekindling a ‘Love of Life not found.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
for i in range(min(5, len(tmdb_movies_list))):
    formatted_result = json.dumps(tmdb_movies_list[i], indent=4)
    print(formatted_result)
    print("\n")
# Out:
# {
#     "title": "The Attachment Diaries",
#     "original_title": "El apego",
#     "budget": 0,
#     "original_language": "es",
#     "homepage": "",
#     "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#     "popularity": 2.338,
#     "runtime": 102,
#     "revenue": 0,
#     "release_date": "2021-10-07",
#     "vote_average": 3.0,
#     "vote_count": 4,
#     "genres": [
#         "Drama",
#         "Mystery",
#         "Thriller",
#         "Horror"
#     ],
#     "spoken_languages": [
#         "Spanish"
#     ],
#     "production_countries": [
#         "Argentina"
#     ]
# }
#
#
# {
#     "title": "You Can Live Forever",
#     "original_title": "You Can Live Forever",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#     "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#     "popularity": 25.799,
#     "runtime": 96,
#     "revenue": 15055,
#     "release_date": "2023-03-24",
#     "vote_average": 6.55,
#     "vote_count": 40,
#     "genres": [
#         "Drama",
#         "Romance"
#     ],
#     "spoken_languages": [
#         "English",
#         "French"
#     ],
#     "production_countries": [
#         "Canada",
#         "United States of America"
#     ]
# }
#
#
# {
#     "title": "A Tourist's Guide to Love",
#     "original_title": "A Tourist's Guide to Love",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "https://www.netflix.com/title/81424906",
#     "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#     "popularity": 17.863,
#     "runtime": 96,
#     "revenue": 0,
#     "release_date": "2023-04-21",
#     "vote_average": 6.303,
#     "vote_count": 170,
#     "genres": [
#         "Romance",
#         "Comedy"
#     ],
#     "spoken_languages": [
#         "English",
#         "Vietnamese"
#     ],
#     "production_countries": [
#         "United States of America"
#     ]
# }
#
#
# {
#     "title": "Other People's Children",
#     "original_title": "Les Enfants des autres",
#     "budget": 0,
#     "original_language": "fr",
#     "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#     "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#     "popularity": 7.963,
#     "runtime": 104,
#     "revenue": 84178,
#     "release_date": "2022-09-21",
#     "vote_average": 6.812,
#     "vote_count": 194,
#     "genres": [
#         "Drama",
#         "Comedy"
#     ],
#     "spoken_languages": [
#         "French",
#         "English"
#     ],
#     "production_countries": [
#         "France"
#     ]
# }
#
#
# {
#     "title": "One True Loves",
#     "original_title": "One True Loves",
#     "budget": 0,
#     "original_language": "en",
#     "homepage": "",
#     "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#     "popularity": 12.109,
#     "runtime": 100,
#     "revenue": 37820,
#     "release_date": "2023-04-07",
#     "vote_average": 6.5,
#     "vote_count": 79,
#     "genres": [
#         "Romance",
#         "Comedy",
#         "Drama"
#     ],
#     "spoken_languages": [
#         "English",
#         "Spanish"
#     ],
#     "production_countries": [
#         "Czech Republic",
#         "United States of America"
#     ]
# }

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                          title               original_title    budget  \
# 0       The Attachment Diaries                     El apego         0
# 1         You Can Live Forever         You Can Live Forever         0
# 2    A Tourist's Guide to Love    A Tourist's Guide to Love         0
# 3      Other People's Children       Les Enfants des autres         0
# 4               One True Loves               One True Loves         0
# ..                         ...                          ...       ...
# 149              The Last Face                The Last Face         0
# 150              Lost in Paris              Paris pieds nus         0
# 151             The Other Half               The Other Half         0
# 152     The Ottoman Lieutenant       The Ottoman Lieutenant  40000000
# 153           Mektoub, My Love  Mektoub, My Love: Canto Uno         0
#
#     original_language                                           homepage  \
# 0                  es
# 1                  en  https://gooddeedentertainment.com/you-can-live...
# 2                  en             https://www.netflix.com/title/81424906
# 3                  fr  https://www.wildbunch.biz/movie/other-peoples-...
# 4                  en
# ..                ...                                                ...
# 149                en
# 150                fr
# 151                en                      http://theotherhalfmovie.com/
# 152                en  https://www.uphe.com/movies/the-ottoman-lieute...
# 153                fr  https://www.pathefilms.com/film/mektoubmylovec...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       2.338      102
# 1    When Jaime, a gay teenager, is sent to live in...      25.799       96
# 2    After an unexpected break up, a travel executi...      17.863       96
# 3    Rachel loves her life, her students, her frien...       7.963      104
# 4    Emma and Jesse are living the perfect life tog...      12.109      100
# ..                                                 ...         ...      ...
# 149  Miguel, a heroic Spanish doctor, puts himself ...       9.985      130
# 150  Fiona visits Paris for the first time to assis...       9.218       83
# 151  A grief-stricken man and a bipolar woman fall ...       3.927      103
# 152  Lillie, a determined American woman, ventures ...      19.758      111
# 153  Amin, an aspiring screenwriter living in Paris...      30.939      181
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         3.000           4
# 1      15055   2023-03-24         6.550          40
# 2          0   2023-04-21         6.303         170
# 3      84178   2022-09-21         6.812         194
# 4      37820   2023-04-07         6.500          79
# ..       ...          ...           ...         ...
# 149        0   2017-01-11         5.500         194
# 150        0   2017-01-14         6.000         115
# 151        0   2016-12-02         6.300          24
# 152   413844   2017-03-28         6.163         248
# 153  1200387   2017-09-07         6.709         297
#
#                                  genres           spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]                  [Spanish]
# 1                      [Drama, Romance]          [English, French]
# 2                     [Romance, Comedy]      [English, Vietnamese]
# 3                       [Drama, Comedy]          [French, English]
# 4              [Romance, Comedy, Drama]         [English, Spanish]
# ..                                  ...                        ...
# 149                             [Drama]      [English, Portuguese]
# 150                            [Comedy]                   [French]
# 151                    [Drama, Romance]                  [English]
# 152               [Romance, Drama, War]         [Turkish, English]
# 153                    [Romance, Drama]  [Arabic, English, French]
#
#                            production_countries
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2                    [United States of America]
# 3                                      [France]
# 4    [Czech Republic, United States of America]
# ..                                          ...
# 149                  [United States of America]
# 150                           [Belgium, France]
# 151                                    [Canada]
# 152          [Turkey, United States of America]
# 153                             [France, Italy]
#
# [154 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Remove any duplicate rows based on the 'title' column in both DataFrames
tmdb_df = tmdb_df.drop_duplicates(subset='title')
df_reviews = df_reviews.drop_duplicates(subset='title')

# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(tmdb_df, df_reviews, on="title", how="inner")

# Adjust Pandas display options to show more columns
pd.set_option('display.max_columns', None)

merged_df
# Out:
#                               title                  original_title    budget  \
# 0            The Attachment Diaries                        El apego         0
# 1              You Can Live Forever            You Can Live Forever         0
# 2                    One True Loves                  One True Loves         0
# 3    The Lost Weekend: A Love Story  The Lost Weekend: A Love Story         0
# 4                A Thousand and One              A Thousand and One         0
# ..                              ...                             ...       ...
# 118            In Search of Fellini            In Search of Fellini         0
# 119                   The Last Face                   The Last Face         0
# 120                   Lost in Paris                 Paris pieds nus         0
# 121                  The Other Half                  The Other Half         0
# 122          The Ottoman Lieutenant          The Ottoman Lieutenant  40000000
#
#     original_language                                           homepage  \
# 0                  es
# 1                  en  https://gooddeedentertainment.com/you-can-live...
# 2                  en
# 3                  en                   https://thelostweekendmovie.com/
# 4                  en  https://www.focusfeatures.com/a-thousand-and-one/
# ..                ...                                                ...
# 118                en
# 119                en
# 120                fr
# 121                en                      http://theotherhalfmovie.com/
# 122                en  https://www.uphe.com/movies/the-ottoman-lieute...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       2.338      102
# 1    When Jaime, a gay teenager, is sent to live in...      25.799       96
# 2    Emma and Jesse are living the perfect life tog...      12.109      100
# 3    May Pang lovingly recounts her life in rock & ...      17.731       95
# 4    Struggling but unapologetically living on her ...      17.021      116
# ..                                                 ...         ...      ...
# 118  Lucy, a small-town girl from Ohio, discovers t...       4.523       93
# 119  Miguel, a heroic Spanish doctor, puts himself ...       9.985      130
# 120  Fiona visits Paris for the first time to assis...       9.218       83
# 121  A grief-stricken man and a bipolar woman fall ...       3.927      103
# 122  Lillie, a determined American woman, ventures ...      19.758      111
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         3.000           4
# 1      15055   2023-03-24         6.550          40
# 2      37820   2023-04-07         6.500          79
# 3      77145   2023-04-13         6.000           2
# 4    3395595   2023-03-31         6.872          90
# ..       ...          ...           ...         ...
# 118        0   2017-09-15         5.800          40
# 119        0   2017-01-11         5.500         194
# 120        0   2017-01-14         6.000         115
# 121        0   2016-12-02         6.300          24
# 122   413844   2017-03-28         6.163         248
#
#                                  genres                spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]                       [Spanish]
# 1                      [Drama, Romance]               [English, French]
# 2              [Romance, Comedy, Drama]              [English, Spanish]
# 3                         [Documentary]                       [English]
# 4                        [Drama, Crime]  [English, Spanish, Portuguese]
# ..                                  ...                             ...
# 118                  [Drama, Adventure]                       [English]
# 119                             [Drama]           [English, Portuguese]
# 120                            [Comedy]                        [French]
# 121                    [Drama, Romance]                       [English]
# 122               [Romance, Drama, War]              [Turkish, English]
#
#                            production_countries  \
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2    [Czech Republic, United States of America]
# 3                    [United States of America]
# 4                    [United States of America]
# ..                                          ...
# 118                                          []
# 119                  [United States of America]
# 120                           [Belgium, France]
# 121                                    [Canada]
# 122          [Turkey, United States of America]
#
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/13/movies/one-...
# 3    https://www.nytimes.com/2023/04/13/movies/the-...
# 4    https://www.nytimes.com/2023/03/30/movies/a-th...
# ..                                                 ...
# 118  https://www.nytimes.com/2017/09/14/movies/in-s...
# 119  https://www.nytimes.com/2017/07/27/movies/the-...
# 120  https://www.nytimes.com/2017/06/15/movies/lost...
# 121  https://www.nytimes.com/2017/03/09/movies/the-...
# 122  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3    There’s not much Lennon music heard in this do...  The New York Times
# 4    A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# ..                                                 ...                 ...
# 118  A sheltered young woman enamored of the films ...  The New York Times
# 119  In war-torn Liberia, Charlize Theron and Javie...  The New York Times
# 120  The filmmakers Fiona Gordon and Dominique Abel...  The New York Times
# 121  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 122  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Bracey, Luke (1989- )...
# 3    subject: Documentary Films and Programs;creati...
# 4    subject: Movies;creative_works: A Thousand and...
# ..                                                 ...
# 118  subject: Movies;creative_works: In Search of F...
# 119  subject: Movies;creative_works: The Last Face ...
# 120  creative_works: Lost in Paris (Movie);subject:...
# 121  subject: Movies;creative_works: The Other Half...
# 122  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-13T11:00:06+0000         320
# 3    2023-04-13T11:00:03+0000         327
# 4    2023-03-30T18:53:42+0000         971
# ..                        ...         ...
# 118  2017-09-14T11:00:24+0000         272
# 119  2017-07-27T20:29:01+0000         280
# 120  2017-06-15T19:37:09+0000         254
# 121  2017-03-09T21:54:58+0000         251
# 122  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4    ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# ..                                                 ...             ...
# 118  Review: Love of Il Maestro Drives ‘In Search o...            None
# 119  Review: Aid Workers in Love and War in Sean Pe...            None
# 120  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 121  Review: A Combustible Pair Find Love in ‘The O...            None
# 122  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 118                    None
# 119                    None
# 120                    None
# 121                    None
# 122                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                                 You Can Live Forever          None
# 2                                       One True Loves          None
# 3                      The Lost Weekend:  A Love Story          None
# 4              An Unbending Will Meets a Shifting City          None
# ..                                                 ...           ...
# 118                               In Search of Fellini          None
# 119                                      The Last Face          None
# 120                                      Lost in Paris          None
# 121  Review: A Combustible Pair Find Love in ‘The O...          None
# 122  Review: Love as the World Wars, in ‘The Ottoma...          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None  By Elisabeth Vincentelli
# 2           None         None             By Brandon Yu
# 3           None         None            By Glenn Kenny
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 118         None         None        By Monica Castillo
# 119         None         None            By Glenn Kenny
# 120         None         None         By Ben Kenigsberg
# 121         None         None           By Andy Webster
# 122         None         None        By Neil Genzlinger
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2    [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 118  [{'firstname': 'Monica', 'middlename': None, '...                None
# 119  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 120  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 121  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 122  [{'firstname': 'Neil', 'middlename': None, 'la...                None
#
# [123 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists

# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)
    
    # Loop through characters to remove
    for char in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, "")

# Display the fixed DataFrame
merged_df.head()
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#   original_language                                           homepage  \
# 0                es
# 1                en  https://gooddeedentertainment.com/you-can-live...
# 2                en
# 3                en                   https://thelostweekendmovie.com/
# 4                en  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       2.338      102
# 1  When Jaime, a gay teenager, is sent to live in...      25.799       96
# 2  Emma and Jesse are living the perfect life tog...      12.109      100
# 3  May Pang lovingly recounts her life in rock & ...      17.731       95
# 4  Struggling but unapologetically living on her ...      17.021      116
#
#    revenue release_date  vote_average  vote_count  \
# 0        0   2021-10-07         3.000           4
# 1    15055   2023-03-24         6.550          40
# 2    37820   2023-04-07         6.500          79
# 3    77145   2023-04-13         6.000           2
# 4  3395595   2023-03-31         6.872          90
#
#                              genres              spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror                       Spanish
# 1                    Drama, Romance               English, French
# 2            Romance, Comedy, Drama              English, Spanish
# 3                       Documentary                       English
# 4                      Drama, Crime  English, Spanish, Portuguese
#
#                        production_countries  \
# 0                                 Argentina
# 1          Canada, United States of America
# 2  Czech Republic, United States of America
# 3                  United States of America
# 4                  United States of America
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;persons: Bracey, Luke (1989- )...
# 3  subject: Documentary Films and Programs;creati...
# 4  subject: Movies;creative_works: A Thousand and...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  \
# 0                    None                   The Attachment Diaries
# 1                    None                     You Can Live Forever
# 2                    None                           One True Loves
# 3                    None          The Lost Weekend:  A Love Story
# 4                    None  An Unbending Will Meets a Shifting City
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None  By Elisabeth Vincentelli
# 2          None         None         None             By Brandon Yu
# 3          None         None         None            By Glenn Kenny
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=["byline.person"])

# %%
# Delete duplicate rows and reset index
merged_df = merged_df.drop_duplicates(subset='title')
merged_df = merged_df.reset_index(drop=True)
merged_df.head()
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#   original_language                                           homepage  \
# 0                es
# 1                en  https://gooddeedentertainment.com/you-can-live...
# 2                en
# 3                en                   https://thelostweekendmovie.com/
# 4                en  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       2.338      102
# 1  When Jaime, a gay teenager, is sent to live in...      25.799       96
# 2  Emma and Jesse are living the perfect life tog...      12.109      100
# 3  May Pang lovingly recounts her life in rock & ...      17.731       95
# 4  Struggling but unapologetically living on her ...      17.021      116
#
#    revenue release_date  vote_average  vote_count  \
# 0        0   2021-10-07         3.000           4
# 1    15055   2023-03-24         6.550          40
# 2    37820   2023-04-07         6.500          79
# 3    77145   2023-04-13         6.000           2
# 4  3395595   2023-03-31         6.872          90
#
#                              genres              spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror                       Spanish
# 1                    Drama, Romance               English, French
# 2            Romance, Comedy, Drama              English, Spanish
# 3                       Documentary                       English
# 4                      Drama, Crime  English, Spanish, Portuguese
#
#                        production_countries  \
# 0                                 Argentina
# 1          Canada, United States of America
# 2  Czech Republic, United States of America
# 3                  United States of America
# 4                  United States of America
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;persons: Bracey, Luke (1989- )...
# 3  subject: Documentary Films and Programs;creati...
# 4  subject: Movies;creative_works: A Thousand and...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  \
# 0                    None                   The Attachment Diaries
# 1                    None                     You Can Live Forever
# 2                    None                           One True Loves
# 3                    None          The Lost Weekend:  A Love Story
# 4                    None  An Unbending Will Meets a Shifting City
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None  By Elisabeth Vincentelli
# 2          None         None         None             By Brandon Yu
# 3          None         None         None            By Glenn Kenny
# 4          None         None         None         By Manohla Dargis
#
#   byline.organization
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None

# %%
# Export data to CSV without the index
merged_df.to_csv("merged_data.csv", index=False)
